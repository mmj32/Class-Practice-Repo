# %% [markdown]
# # Pandas notes
#     some nots of bao yun
#     import a csv file of relative clause sentences from a self paced reading task
#     calculate the average times of the critical and spillover regions of oblique relative clauses
#     example of oblique
#         Ichiro-wa [Koji-ga tomatta hotel]-o yoyakusita.
#         Ichiro reserved [the hotel in which Koji stayed].
#     in Japanese, it has been argued that subject, object, and oblique relatives are all processed similarly by L1 speakers. let's examine if L2 learners of Japanese (L1 Chinese and L1 Korean) show any slowdown in processing.
#     to do this, we will examine the average reading times of region 2 (where the second subject appears), region 3 (where the oblique is), and region 4 (the object of the oblique).

# %%
#import pandas as pd
import pandas as pd

#import the csv file
#this is the csv file of relative clauses
rc = pd.read_csv("RelativeClauses.csv")

print(rc[:10])
# Out:
#          L1  Subject  Region    Word  Time  Sentence Case  Order  Reflexive  \
# 0  Japanese        1       1     ???   464        49    R     23  Simple S1
# 1  Japanese        1       2     ???   389        49    R     23  Simple S1
# 2  Japanese        1       3  ??????   409        49    R     23  Simple S1
# 3  Japanese        1       4     ???   378        49    R     23  Simple S1
# 4  Japanese        1       5       ?   650        49    R     23  Simple S1
# 5  Japanese        1       6      TF   764        49    R     23  Simple S1
# 6  Japanese        2       1     ???   425        49    R     26  Simple S1
# 7  Japanese        2       2     ???   369        49    R     26  Simple S1
# 8  Japanese        2       3  ??????   767        49    R     26  Simple S1
# 9  Japanese        2       4     ???   288        49    R     26  Simple S1
#
#   Predicate  Binding
# 0    Simple    False
# 1    Simple    False
# 2    Simple    False
# 3    Simple    False
# 4    Simple    False
# 5    Simple    False
# 6    Simple    False
# 7    Simple    False
# 8    Simple    False
# 9    Simple    False

# %% [markdown]
# ### This is a csv file from a self paced reading task in Japanese.
#     The sentences are comparing between simple clauses and relative clauses.
#     The L1s are L1 Japanese and L1 Chinese and L1 Korean learners of L2 Japanese.
#     All subjects are marked by numeral 1-n
#     The regions indicate the phrase number.
#     When we originally imported the file from LINGER to Excel, something got messed up and all the MS Mincho Japanese font did not carry over (we tried UTF-8 when convering to csv but it still didn't work). But that's not as important.
#     We are going to look at whether there are differences in the critical regions of oblique relative clauses.
#     Thus, the colums of interest are:
#         L1, Region, Time, and Predicate
#     The rows of interest are only
#         Region 2, 3, 4
#     This is where some of the weird things may happen for L2 learners.

# %% [markdown]
#     Next, we should print out and see some of the info of the columns of interest.
#     We don't need to fix by including an index_col becuase that was already done in the previous work from R (as shown)

# %%
print(rc[['L1', 'Region', 'Time', 'Predicate']])
# Out:
#             L1  Region  Time Predicate
# 0     Japanese       1   464    Simple
# 1     Japanese       2   389    Simple
# 2     Japanese       3   409    Simple
# 3     Japanese       4   378    Simple
# 4     Japanese       5   650    Simple
# 5     Japanese       6   764    Simple
# 6     Japanese       1   425    Simple
# 7     Japanese       2   369    Simple
# 8     Japanese       3   767    Simple
# 9     Japanese       4   288    Simple
# 10    Japanese       5   239    Simple
# 11    Japanese       6  1146    Simple
# 12    Japanese       1   353    Simple
# 13    Japanese       2   276    Simple
# 14    Japanese       3   246    Simple
# 15    Japanese       4   524    Simple
# 16    Japanese       5   286    Simple
# 17    Japanese       6   891    Simple
# 18    Japanese       1   473    Simple
# 19    Japanese       2   416    Simple
# 20    Japanese       3   624    Simple
# 21    Japanese       4   316    Simple
# 22    Japanese       5   246    Simple
# 23    Japanese       6   563    Simple
# 24    Japanese       1   591    Simple
# 25    Japanese       2   474    Simple
# 26    Japanese       3   663    Simple
# 27    Japanese       4   325    Simple
# 28    Japanese       5   306    Simple
# 29    Japanese       6  1447    Simple
# ...        ...     ...   ...       ...
# 3694   Chinese       6   363   Oblique
# 3695   Chinese       7   739   Oblique
# 3696   Chinese       1   524   Oblique
# 3697   Chinese       2  1207   Oblique
# 3698   Chinese       3  4735   Oblique
# 3699   Chinese       4   577   Oblique
# 3700   Chinese       5  1027   Oblique
# 3701   Chinese       6  4665   Oblique
# 3702   Chinese       7  2725   Oblique
# 3703   Chinese       1   670   Oblique
# 3704   Chinese       2  1309   Oblique
# 3705   Chinese       3  4170   Oblique
# 3706   Chinese       4   684   Oblique
# 3707   Chinese       5  1557   Oblique
# 3708   Chinese       6  1796   Oblique
# 3709   Chinese       7  1149   Oblique
# 3710   Chinese       1   482   Oblique
# 3711   Chinese       2   673   Oblique
# 3712   Chinese       3  1458   Oblique
# 3713   Chinese       4   891   Oblique
# 3714   Chinese       5   554   Oblique
# 3715   Chinese       6   594   Oblique
# 3716   Chinese       7  1238   Oblique
# 3717   Chinese       1   427   Oblique
# 3718   Chinese       2   699   Oblique
# 3719   Chinese       3  4853   Oblique
# 3720   Chinese       4   559   Oblique
# 3721   Chinese       5   980   Oblique
# 3722   Chinese       6   389   Oblique
# 3723   Chinese       7  1261   Oblique
#
# [3724 rows x 4 columns]

# %% [markdown]
# ### next steps to trim down data of interest
#     As we can see there are 3723 rows of data, but since there are only 3 rows of interest for each sentence, this will essentially trim down to 3723/3 = 1241 data points of interest.
#
#     Mind you that if we included Subject and Object relative clauses this would be triple, which is why I am only looking at Subject for now.
#
#     Print out a subset data frame that includes only the regions of interest (2, 3, and 4)

# %%
rcob = rc[rc.Predicate == 'Oblique']
print(rcob)
# Out:
#             L1  Subject  Region   Word  Time  Sentence Case  Order  \
# 1302  Japanese        1       1    ???   454        58    R      8
# 1303  Japanese        1       2    ???   339        58    R      8
# 1304  Japanese        1       3   ????   349        58    R      8
# 1305  Japanese        1       4   ????   369        58    R      8
# 1306  Japanese        1       5   ????   599        58    R      8
# 1307  Japanese        1       6      ?   609        58    R      8
# 1308  Japanese        1       7     TF   885        58    R      8
# 1309  Japanese        2       1    ???   636        58    R     25
# 1310  Japanese        2       2    ???   549        58    R     25
# 1311  Japanese        2       3   ????   758        58    R     25
# 1312  Japanese        2       4   ????   477        58    R     25
# 1313  Japanese        2       5   ????   719        58    R     25
# 1314  Japanese        2       6      ?   458        58    R     25
# 1315  Japanese        2       7     TF  1277        58    R     25
# 1316  Japanese        3       1    ???   412        58    R     10
# 1317  Japanese        3       2    ???   386        58    R     10
# 1318  Japanese        3       3   ????   304        58    R     10
# 1319  Japanese        3       4   ????   534        58    R     10
# 1320  Japanese        3       5   ????   355        58    R     10
# 1321  Japanese        3       6      ?   386        58    R     10
# 1322  Japanese        3       7     TF  2916        58    R     10
# 1323  Japanese        4       1    ???   561        58    R     58
# 1324  Japanese        4       2    ???   715        58    R     58
# 1325  Japanese        4       3   ????   356        58    R     58
# 1326  Japanese        4       4   ????   386        58    R     58
# 1327  Japanese        4       5   ????   376        58    R     58
# 1328  Japanese        4       6      ?   336        58    R     58
# 1329  Japanese        4       7     TF   782        58    R     58
# 1330  Japanese        5       1    ???   412        58    R     55
# 1331  Japanese        5       2    ???   414        58    R     55
# ...        ...      ...     ...    ...   ...       ...  ...    ...
# 3694   Chinese      211       6      ?   363        60    R     23
# 3695   Chinese      211       7     TF   739        60    R     23
# 3696   Chinese      212       1    ???   524        60    R      3
# 3697   Chinese      212       2    ???  1207        60    R      3
# 3698   Chinese      212       3  ?????  4735        60    R      3
# 3699   Chinese      212       4    ???   577        60    R      3
# 3700   Chinese      212       5    ???  1027        60    R      3
# 3701   Chinese      212       6      ?  4665        60    R      3
# 3702   Chinese      212       7     TF  2725        60    R      3
# 3703   Chinese      213       1    ???   670        60    R     46
# 3704   Chinese      213       2    ???  1309        60    R     46
# 3705   Chinese      213       3  ?????  4170        60    R     46
# 3706   Chinese      213       4    ???   684        60    R     46
# 3707   Chinese      213       5    ???  1557        60    R     46
# 3708   Chinese      213       6      ?  1796        60    R     46
# 3709   Chinese      213       7     TF  1149        60    R     46
# 3710   Chinese      214       1    ???   482        60    R     37
# 3711   Chinese      214       2    ???   673        60    R     37
# 3712   Chinese      214       3  ?????  1458        60    R     37
# 3713   Chinese      214       4    ???   891        60    R     37
# 3714   Chinese      214       5    ???   554        60    R     37
# 3715   Chinese      214       6      ?   594        60    R     37
# 3716   Chinese      214       7     TF  1238        60    R     37
# 3717   Chinese      215       1    ???   427        60    R     21
# 3718   Chinese      215       2    ???   699        60    R     21
# 3719   Chinese      215       3  ?????  4853        60    R     21
# 3720   Chinese      215       4    ???   559        60    R     21
# 3721   Chinese      215       5    ???   980        60    R     21
# 3722   Chinese      215       6      ?   389        60    R     21
# 3723   Chinese      215       7     TF  1261        60    R     21
#
#         Reflexive Predicate  Binding
# 1302  Relative B1   Oblique     True
# 1303  Relative B1   Oblique     True
# 1304  Relative B1   Oblique     True
# 1305  Relative B1   Oblique     True
# 1306  Relative B1   Oblique     True
# 1307  Relative B1   Oblique     True
# 1308  Relative B1   Oblique     True
# 1309  Relative B1   Oblique     True
# 1310  Relative B1   Oblique     True
# 1311  Relative B1   Oblique     True
# 1312  Relative B1   Oblique     True
# 1313  Relative B1   Oblique     True
# 1314  Relative B1   Oblique     True
# 1315  Relative B1   Oblique     True
# 1316  Relative B1   Oblique     True
# 1317  Relative B1   Oblique     True
# 1318  Relative B1   Oblique     True
# 1319  Relative B1   Oblique     True
# 1320  Relative B1   Oblique     True
# 1321  Relative B1   Oblique     True
# 1322  Relative B1   Oblique     True
# 1323  Relative B1   Oblique     True
# 1324  Relative B1   Oblique     True
# 1325  Relative B1   Oblique     True
# 1326  Relative B1   Oblique     True
# 1327  Relative B1   Oblique     True
# 1328  Relative B1   Oblique     True
# 1329  Relative B1   Oblique     True
# 1330  Relative B1   Oblique     True
# 1331  Relative B1   Oblique     True
# ...           ...       ...      ...
# 3694  Relative B2   Oblique    False
# 3695  Relative B2   Oblique    False
# 3696  Relative B2   Oblique    False
# 3697  Relative B2   Oblique    False
# 3698  Relative B2   Oblique    False
# 3699  Relative B2   Oblique    False
# 3700  Relative B2   Oblique    False
# 3701  Relative B2   Oblique    False
# 3702  Relative B2   Oblique    False
# 3703  Relative B2   Oblique    False
# 3704  Relative B2   Oblique    False
# 3705  Relative B2   Oblique    False
# 3706  Relative B2   Oblique    False
# 3707  Relative B2   Oblique    False
# 3708  Relative B2   Oblique    False
# 3709  Relative B2   Oblique    False
# 3710  Relative B2   Oblique    False
# 3711  Relative B2   Oblique    False
# 3712  Relative B2   Oblique    False
# 3713  Relative B2   Oblique    False
# 3714  Relative B2   Oblique    False
# 3715  Relative B2   Oblique    False
# 3716  Relative B2   Oblique    False
# 3717  Relative B2   Oblique    False
# 3718  Relative B2   Oblique    False
# 3719  Relative B2   Oblique    False
# 3720  Relative B2   Oblique    False
# 3721  Relative B2   Oblique    False
# 3722  Relative B2   Oblique    False
# 3723  Relative B2   Oblique    False
#
# [686 rows x 11 columns]

# %% [markdown]
# ### next trim the data furthe down to just show regions 2, 3, and 4 in the data frame
#     so apparently i don't think i can remove a bunch of rows at once, unless i am doing something wrong (i.e., i can do rcob.Region != 1, but cannot do 1, 5, 6 etc.
#     thus, the following removes Regions 1, 5, 6, and 7 separately through != codes, and then prints out regions 234 only, as shown
#     don't forget [[]] to show only the columns of interest
#     ^actually just save it as a code

# %%
rcob1 = rcob[rcob.Region != 1]
rcob5 = rcob1[rcob1.Region != 5]
rcob6 = rcob5[rcob5.Region != 6]
rcob7 = rcob6[rcob6.Region != 7]
rcob234 = rcob7[['L1', 'Region', 'Time', 'Reflexive']]
print(rcob234)
# Out:
#             L1  Region  Time    Reflexive
# 1303  Japanese       2   339  Relative B1
# 1304  Japanese       3   349  Relative B1
# 1305  Japanese       4   369  Relative B1
# 1310  Japanese       2   549  Relative B1
# 1311  Japanese       3   758  Relative B1
# 1312  Japanese       4   477  Relative B1
# 1317  Japanese       2   386  Relative B1
# 1318  Japanese       3   304  Relative B1
# 1319  Japanese       4   534  Relative B1
# 1324  Japanese       2   715  Relative B1
# 1325  Japanese       3   356  Relative B1
# 1326  Japanese       4   386  Relative B1
# 1331  Japanese       2   414  Relative B1
# 1332  Japanese       3   475  Relative B1
# 1333  Japanese       4   355  Relative B1
# 1338  Japanese       2   438  Relative B1
# 1339  Japanese       3   438  Relative B1
# 1340  Japanese       4   378  Relative B1
# 1345  Japanese       2   565  Relative B1
# 1346  Japanese       3   497  Relative B1
# 1347  Japanese       4   383  Relative B1
# 1352  Japanese       2   487  Relative B1
# 1353  Japanese       3   496  Relative B1
# 1354  Japanese       4   457  Relative B1
# 1359  Japanese       2   388  Relative B1
# 1360  Japanese       3   389  Relative B1
# 1361  Japanese       4   358  Relative B1
# 1366  Japanese       2   435  Relative B1
# 1367  Japanese       3   435  Relative B1
# 1368  Japanese       4   405  Relative B1
# ...        ...     ...   ...          ...
# 3655   Chinese       2   806  Relative B2
# 3656   Chinese       3  1235  Relative B2
# 3657   Chinese       4   367  Relative B2
# 3662   Chinese       2  1193  Relative B2
# 3663   Chinese       3  1641  Relative B2
# 3664   Chinese       4   426  Relative B2
# 3669   Chinese       2   428  Relative B2
# 3670   Chinese       3   658  Relative B2
# 3671   Chinese       4   358  Relative B2
# 3676   Chinese       2   511  Relative B2
# 3677   Chinese       3   915  Relative B2
# 3678   Chinese       4  1018  Relative B2
# 3683   Chinese       2  1562  Relative B2
# 3684   Chinese       3  1134  Relative B2
# 3685   Chinese       4  1106  Relative B2
# 3690   Chinese       2   275  Relative B2
# 3691   Chinese       3   753  Relative B2
# 3692   Chinese       4   520  Relative B2
# 3697   Chinese       2  1207  Relative B2
# 3698   Chinese       3  4735  Relative B2
# 3699   Chinese       4   577  Relative B2
# 3704   Chinese       2  1309  Relative B2
# 3705   Chinese       3  4170  Relative B2
# 3706   Chinese       4   684  Relative B2
# 3711   Chinese       2   673  Relative B2
# 3712   Chinese       3  1458  Relative B2
# 3713   Chinese       4   891  Relative B2
# 3718   Chinese       2   699  Relative B2
# 3719   Chinese       3  4853  Relative B2
# 3720   Chinese       4   559  Relative B2
#
# [294 rows x 4 columns]

# %% [markdown]
# next, find the average reading times of regions 2, 3, and 4
# separate the L1s
# the code for this is
#
# means = rcob234.groupby('L1', as_index=False)['Time'].mean()
# print(means)
#
# ***note = but this will only print out the total average tiimes
# not sure how to print out 2, 3, and 4 separately
# To use loc, we may need to index L1s, but there should be a way to do it w/o it?
#
# at least there is a way to do it as below.
# This shows some results, maybe not as clean as it can be (I am looking for a way to do it where it also shows Japanese)

# %%
Jrcob = rcob234[rcob234.L1 == 'Japanese']
Krcob = rcob234[rcob234.L1 == 'Korean']
Crcob = rcob234[rcob234.L1 == 'Chinese']

Jrcob_meanRT = Jrcob.groupby(['Region'], as_index=False).mean()
print(Jrcob_meanRT)

Krcob_meanRT = Krcob.groupby(['Region'], as_index=False).mean()
print(Krcob_meanRT)

Crcob_meanRT = Crcob.groupby(['Region'], as_index=False).mean()
print(Crcob_meanRT)
# Out:
#    Region        Time
# 0       2  515.809524
# 1       3  533.738095
# 2       4  649.690476
#    Region       Time
# 0       2   829.6875
# 1       3  1211.8125
# 2       4   588.9375
#    Region      Time
# 0       2   718.075
# 1       3  1307.275
# 2       4   613.075
