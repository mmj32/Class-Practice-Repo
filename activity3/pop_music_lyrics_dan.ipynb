# %%
import pandas as pd

# %%
df = pd.read_csv('billboard_lyrics_1964-2015.csv', encoding='latin1')
print(df.head())
# Out:
#    Rank                                      Song  \
# 0     1                               wooly bully
# 1     2  i cant help myself sugar pie honey bunch
# 2     3                i cant get no satisfaction
# 3     4                       you were on my mind
# 4     5              youve lost that lovin feelin
#
#                           Artist  Year  \
# 0  sam the sham and the pharaohs  1965
# 1                      four tops  1965
# 2             the rolling stones  1965
# 3                        we five  1965
# 4         the righteous brothers  1965
#
#                                               Lyrics  Source
# 0  sam the sham miscellaneous wooly bully wooly b...     3.0
# 1   sugar pie honey bunch you know that i love yo...     1.0
# 2                                                        1.0
# 3   when i woke up this morning you were on my mi...     1.0
# 4   you never close your eyes anymore when i kiss...     1.0

# %%
print(df['Year'].value_counts().sort(key='Year'))
print(list(df.groupby(['Year']).size()) == [100]*len(set(df['Year'])))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-1705dde5134a> in <module>()
# ----> 1 print(df['Year'].value_counts().sort(key='Year'))
#       2 print(list(df.groupby(['Year']).size()) == [100]*len(set(df['Year'])))
#
# ~/venv3/lib/python3.5/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'sort'

# %%
df_old = df[df['Year'] == 1965]
df_new = df[df['Year'] == 2005]

# %%
df.tail(100)
# Out:
#       Rank                    Song  \
# 5000     1             uptown funk
# 5001     2       thinking out loud
# 5002     3           see you again
# 5003     4              trap queen
# 5004     5                   sugar
# 5005     6       shut up and dance
# 5006     7             blank space
# 5007     8                watch me
# 5008     9               earned it
# 5009    10               the hills
# 5010    11             cheerleader
# 5011    12       cant feel my face
# 5012    13     love me like you do
# 5013    14       take me to church
# 5014    15               bad blood
# 5015    16                 lean on
# 5016    17         want to want me
# 5017    18            shake it off
# 5018    19        where are "u now
# 5019    20              fight song
# 5020    21                     679
# 5021    22          lips are movin
# 5022    23                worth it
# 5023    24              post to be
# 5024    25           honey im good
# ...
