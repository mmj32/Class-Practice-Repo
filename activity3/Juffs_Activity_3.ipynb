# %% [markdown]
# Class Activity 3
# Alan Juffs
# Workbook for Bill Board Top 1000

# %%
import pandas as pd
songs = pd.read_csv('/Users/Juffs/Documents/billboard_lyrics_1964-2015.csv', encoding ='cp1252')

# %% [markdown]
# You may have to find the encoding of the files.

# %%
songs.tail(5)
# Out:
#       Rank                   Song                          Artist  Year  \
# 5095    96              el perdon  nicky jam and enrique iglesias  2015
# 5096    97              she knows          neyo featuring juicy j  2015
# 5097    98          night changes                   one direction  2015
# 5098    99           back to back                           drake  2015
# 5099   100  how deep is your love     calvin harris and disciples  2015
#
#                                                  Lyrics  Source
# 5095  enrique iglesias dime si es verdad me dijeron ...     3.0
# 5096                                                NaN     NaN
# 5097   going out tonight changes into something red ...     1.0
# 5098   oh man oh man oh man not againyeah i learned ...     1.0
# 5099   i want you to breathe me in let me be your ai...     1.0

# %% [markdown]
# songs.head() and songs.tail() will flash first and last 5 songs.
#
# songs.info - rank 5100 entries all present and also integers
# Song non null object .. it's string.
# Lyrics - not all songs have lyrics
# Source - three databases on the internet.
#
# songs.describe() provides some statistical information. Pandas saw colums as numbers.

# %%
songs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5100 entries, 0 to 5099
# Data columns (total 6 columns):
# Rank      5100 non-null int64
# Song      5100 non-null object
# Artist    5100 non-null object
# Year      5100 non-null int64
# Lyrics    4913 non-null object
# Source    4913 non-null float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 239.1+ KB

# %% [markdown]
# songs.head(20)

# %%
songs.head(20)
# Out:
#     Rank                                      Song  \
# 0      1                               wooly bully
# 1      2  i cant help myself sugar pie honey bunch
# 2      3                i cant get no satisfaction
# 3      4                       you were on my mind
# 4      5              youve lost that lovin feelin
# 5      6                                  downtown
# 6      7                                      help
# 7      8               cant you hear my heart beat
# 8      9                      crying in the chapel
# 9     10                                   my girl
# 10    11                            help me rhonda
# 11    12                          king of the road
# 12    13                    the birds and the bees
# 13    14                 hold me thrill me kiss me
# 14    15                                   shotgun
# 15    16                            i got you babe
# 16    17                         this diamond ring
# ...

# %% [markdown]
# Reorder the columns and delete the source column. [[ ]] is important for a dataframe.

# %%
songs= songs [['Year', 'Rank', 'Artist', 'Song', 'Lyrics']]
type(songs)
songs.head()
# Out:
#    Year  Rank                         Artist  \
# 0  1965     1  sam the sham and the pharaohs
# 1  1965     2                      four tops
# 2  1965     3             the rolling stones
# 3  1965     4                        we five
# 4  1965     5         the righteous brothers
#
#                                        Song  \
# 0                               wooly bully
# 1  i cant help myself sugar pie honey bunch
# 2                i cant get no satisfaction
# 3                       you were on my mind
# 4              youve lost that lovin feelin
#
#                                               Lyrics
# 0  sam the sham miscellaneous wooly bully wooly b...
# 1   sugar pie honey bunch you know that i love yo...
# 2
# 3   when i woke up this morning you were on my mi...
# 4   you never close your eyes anymore when i kiss...

# %%
songs= songs [['Year', 'Rank', 'Artist', 'Song', 'Lyrics']]
type(songs)
songs.head(50)
# Out:
#     Year  Rank                          Artist  \
# 0   1965     1   sam the sham and the pharaohs
# 1   1965     2                       four tops
# 2   1965     3              the rolling stones
# 3   1965     4                         we five
# 4   1965     5          the righteous brothers
# 5   1965     6                    petula clark
# 6   1965     7                     the beatles
# 7   1965     8                 hermans hermits
# 8   1965     9                   elvis presley
# 9   1965    10                 the temptations
# 10  1965    11                  the beach boys
# 11  1965    12                    roger miller
# 12  1965    13                     jewel akens
# 13  1965    14                      mel carter
# 14  1965    15    junior walker  the all stars
# 15  1965    16                     sonny  cher
# 16  1965    17        gary lewis  the playboys
# 17  1965    18               ramsey lewis trio
# 18  1965    19                 hermans hermits
# ...

# %% [raw]
# print(songs['Lyrics]'[2])

# %%
songs.loc[48] #all the row
# Out:
# Year                                                   1965
# Rank                                                     49
# Artist                                       the beach boys
# Song                                       california girls
# Lyrics    well east coast girls are hip i really dig tho...
# Name: 48, dtype: object

# %%
songs.loc[48, 'Lyrics']
# Out:
# 'well east coast girls are hip i really dig those styles they wear and the southern girls with the way they talk they knock me out when im down there the midwest farmers daughter really makes you feel alright and the northern girls with the way they kiss they keep their boyfriends warm at night i wish they all could be california wish they all could be california i wish they all could be california girls the west coast has the sunshine and the girls all get so tan i dig a french bikini on hawiian island dollsby a palm tree in the sand i been all round this great big world and i seen all kinds of girls yeah but i couldnt wait to get back in the states back to the cutest girls in the world i wish they all could be california wish they all could be california i wish they all could be california girls i wish they all could be california wish they all could be california i wish they all could be california girls'

# %%
songs.iloc[48, 4]
#songs.loc [row + index]
# Out:
# 'well east coast girls are hip i really dig those styles they wear and the southern girls with the way they talk they knock me out when im down there the midwest farmers daughter really makes you feel alright and the northern girls with the way they kiss they keep their boyfriends warm at night i wish they all could be california wish they all could be california i wish they all could be california girls the west coast has the sunshine and the girls all get so tan i dig a french bikini on hawiian island dollsby a palm tree in the sand i been all round this great big world and i seen all kinds of girls yeah but i couldnt wait to get back in the states back to the cutest girls in the world i wish they all could be california wish they all could be california i wish they all could be california girls i wish they all could be california wish they all could be california i wish they all could be california girls'

# %%
#is the data complete? does every year have all 100 entries and are there any missing or anomalous data

# %%
# %pprint
len(set(songs['Year']))
# Out:
# Pretty printing has been turned OFF
# 51

# %%
#pandas is supposed to be more efficient than basic python methods ...so 18 is not an efficient way
#s

# %%
songs['Year'].unique() # add .size for number of years
# Out:
# array([1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975,
#        1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986,
#        1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997,
#        1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008,
#        2009, 2010, 2011, 2012, 2013, 2014, 2015])

# %%
dir(songs['Rank']) # list of possible commands
# Out:
# ['T', '_AXIS_ALIASES', '_AXIS_IALIASES', '_AXIS_LEN', '_AXIS_NAMES', '_AXIS_NUMBERS', '_AXIS_ORDERS', '_AXIS_REVERSED', '_AXIS_SLICEMAP', '__abs__', '__add__', '__and__', '__array__', '__array_prepare__', '__array_priority__', '__array_wrap__', '__bool__', '__bytes__', '__class__', '__contains__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__div__', '__divmod__', '__doc__', '__eq__', '__finalize__', '__float__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__int__', '__invert__', '__ipow__', '__isub__', '__iter__', '__itruediv__', '__le__', '__len__', '__long__', '__lt__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pow__', '__radd__', '__rand__', '__rdiv__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rmod__', '__rmul__', '__ror__', '__
# ...

# %%
songs['Rank'].value_counts().sort_index()
# Out:
# 1      51
# 2      51
# 3      51
# 4      51
# 5      51
# 6      51
# 7      51
# 8      51
# 9      51
# 10     51
# 11     51
# 12     51
# 13     51
# 14     51
# 15     51
# 16     51
# 17     51
# 18     51
# 19     51
# 20     51
# 21     51
# 22     51
# 23     51
# 24     51
# 25     51
# 26     51
# 27     51
# 28     51
# 29     51
# 30     51
#        ..
# 71     51
# 72     51
# 73     51
# 74     51
# 75     51
# 76     51
# 77     51
# 78     51
# 79     51
# 80     51
# 81     51
# 82     51
# 83     51
# 84     51
# 85     51
# 86     51
# 87     51
# 88     51
# 89     51
# 90     51
# 91     51
# 92     51
# 93     51
# 94     51
# 95     51
# 96     51
# 97     51
# 98     51
# 99     51
# 100    51
# Name: Rank, Length: 100, dtype: int64

# %%
# only 1965
#songs['Year'] ==1965 will give you a boolean response.

# %%
#save as 'oldfilter'

oldfilter = songs['Year']== 1965

oldsongs = songs.loc[oldfilter, :]
oldsongs.head
# Out:
# <bound method NDFrame.head of     Year  Rank                            Artist  \
# 0   1965     1     sam the sham and the pharaohs
# 1   1965     2                         four tops
# 2   1965     3                the rolling stones
# 3   1965     4                           we five
# 4   1965     5            the righteous brothers
# 5   1965     6                      petula clark
# 6   1965     7                       the beatles
# 7   1965     8                   hermans hermits
# 8   1965     9                     elvis presley
# 9   1965    10                   the temptations
# 10  1965    11                    the beach boys
# 11  1965    12                      roger miller
# 12  1965    13                       jewel akens
# 13  1965    14                        mel carter
# 14  1965    15      junior walker  the all stars
# 15  1965    16                       sonny  cher
# 16  1965    17          gary lewis  the playboys
# ...

# %%
oldsongs.tail
# Out:
# <bound method NDFrame.tail of     Year  Rank                            Artist  \
# 0   1965     1     sam the sham and the pharaohs
# 1   1965     2                         four tops
# 2   1965     3                the rolling stones
# 3   1965     4                           we five
# 4   1965     5            the righteous brothers
# 5   1965     6                      petula clark
# 6   1965     7                       the beatles
# 7   1965     8                   hermans hermits
# 8   1965     9                     elvis presley
# 9   1965    10                   the temptations
# 10  1965    11                    the beach boys
# 11  1965    12                      roger miller
# 12  1965    13                       jewel akens
# 13  1965    14                        mel carter
# 14  1965    15      junior walker  the all stars
# 15  1965    16                       sonny  cher
# 16  1965    17          gary lewis  the playboys
# ...

# %%
#Last 100 entries
#slice 100 
#oldsongs = songs.iloc[:100, :]
#oldies songs.loc[songs['Year'] == 1965]
newsongs = songs.iloc [-100, :]

# %%
millienial = songs.loc[songs['Year'] >= 2000, :]

# %%
millienial.info
# Out:
# <bound method DataFrame.info of       Year  Rank                                             Artist  \
# 3500  2000     1                                         faith hill
# 3501  2000     2                       santana featuring rob thomas
# 3502  2000     3                   santana featuring the product gb
# 3503  2000     4                                                joe
# 3504  2000     5                                   vertical horizon
# 3505  2000     6                                     destinys child
# 3506  2000     7                                      savage garden
# 3507  2000     8                                           lonestar
# 3508  2000     9                                    matchbox twenty
# 3509  2000    10                                       toni braxton
# 3510  2000    11                                              creed
# 3511  2000    12                                            aaliyah
# ...

# %%
songs.loc[songs['Artist'] =='madonna' , :]
# Out:
#       Year  Rank   Artist                           Song  \
# 1934  1984    35  madonna                     borderline
# 1965  1984    66  madonna                     lucky star
# 1978  1984    79  madonna                        holiday
# 2001  1985     2  madonna                  like a virgin
# 2008  1985     9  madonna                  crazy for you
# 2057  1985    58  madonna                  material girl
# 2080  1985    81  madonna                          angel
# 2097  1985    98  madonna                   dress you up
# 2128  1986    29  madonna               papa dont preach
# 2134  1986    35  madonna                   live to tell
# 2175  1986    76  madonna                      true blue
# 2229  1987    30  madonna                open your heart
# 2241  1987    42  madonna                 whos that girl
# 2245  1987    46  madonna            causing a commotion
# 2257  1987    58  madonna                 la isla bonita
# ...

# %%
newsongs = songs.iloc [-100, :]

# %%
newsongs.head
# Out:
# <bound method NDFrame.head of Year                                                   2015
# Rank                                                      1
# Artist                     mark ronson featuring bruno mars
# Song                                            uptown funk
# Lyrics     this hit that ice cold michelle pfeiffer that...
# Name: 5000, dtype: object>

# %%
oldfilter = songs['Year']== 1965

oldsongs = songs.loc[oldfilter, :]
oldsongs.head
# Out:
# <bound method NDFrame.head of     Year  Rank                            Artist  \
# 0   1965     1     sam the sham and the pharaohs
# 1   1965     2                         four tops
# 2   1965     3                the rolling stones
# 3   1965     4                           we five
# 4   1965     5            the righteous brothers
# 5   1965     6                      petula clark
# 6   1965     7                       the beatles
# 7   1965     8                   hermans hermits
# 8   1965     9                     elvis presley
# 9   1965    10                   the temptations
# 10  1965    11                    the beach boys
# 11  1965    12                      roger miller
# 12  1965    13                       jewel akens
# 13  1965    14                        mel carter
# 14  1965    15      junior walker  the all stars
# 15  1965    16                       sonny  cher
# 16  1965    17          gary lewis  the playboys
# ...

# %%
#madonna songs 2000 or later
songs.loc[(songs'Artists']== 'madonna') & (songs["year"] >2000, :)
# Out:
#   File "<ipython-input-27-a1276625eb5c>", line 2
#     songs.loc[(songs'Artists']== 'madonna') & (songs["year"] >2000, :)
#                             ^
# SyntaxError: invalid syntax

# %%
len(songs['Artist'].unique().size
# Out:
#   File "<ipython-input-38-da3af251b99c>", line 1
#     len(songs['Artist'].unique().size
#                                      ^
# SyntaxError: unexpected EOF while parsing

# %%
songs['Artist'].value_counts()
# Out:
# madonna                                                 35
# elton john                                              26
# mariah carey                                            25
# michael jackson                                         22
# janet jackson                                           22
# stevie wonder                                           22
# rihanna                                                 19
# taylor swift                                            19
# whitney houston                                         19
# kelly clarkson                                          17
# pink                                                    17
# the beatles                                             17
# britney spears                                          16
# the black eyed peas                                     16
# chicago                                                 15
# usher                                                   14
# ...

# %%
#create another column

# %%
songs.head()
# Out:
#    Year  Rank                         Artist  \
# 0  1965     1  sam the sham and the pharaohs
# 1  1965     2                      four tops
# 2  1965     3             the rolling stones
# 3  1965     4                        we five
# 4  1965     5         the righteous brothers
#
#                                        Song  \
# 0                               wooly bully
# 1  i cant help myself sugar pie honey bunch
# 2                i cant get no satisfaction
# 3                       you were on my mind
# 4              youve lost that lovin feelin
#
#                                               Lyrics
# 0  sam the sham miscellaneous wooly bully wooly b...
# 1   sugar pie honey bunch you know that i love yo...
# 2
# 3   when i woke up this morning you were on my mi...
# 4   you never close your eyes anymore when i kiss...

# %%
len(songs.loc[0, 'Lyrics'].split()) # split tokenize
# Out:
# 125

# %%
songs = songs.fillna('')
songs[:50]
foo = songs [:50]
for x in songs ['Lyrics']
    print(x.split)
# Out:
#   File "<ipython-input-48-bca0bf04d116>", line 4
#     for x in songs ['Lyrics']
#                              ^
# SyntaxError: invalid syntax

# %%
foo 
[x.split()]) for x in songs["Lyrics"]]

# %%
songs['length'] = pd.series(toklengths)

# %%
def tokenize(txt):
    return txt.split()
songs['tokens'] = songs['Lyrics'].map(tokenize) #good way to add column

# %%
songs.head()
# Out:
#    Year  Rank                         Artist  \
# 0  1965     1  sam the sham and the pharaohs
# 1  1965     2                      four tops
# 2  1965     3             the rolling stones
# 3  1965     4                        we five
# 4  1965     5         the righteous brothers
#
#                                        Song  \
# 0                               wooly bully
# 1  i cant help myself sugar pie honey bunch
# 2                i cant get no satisfaction
# 3                       you were on my mind
# 4              youve lost that lovin feelin
#
#                                               Lyrics  \
# 0  sam the sham miscellaneous wooly bully wooly b...
# 1   sugar pie honey bunch you know that i love yo...
# 2
# 3   when i woke up this morning you were on my mi...
# 4   you never close your eyes anymore when i kiss...
#
#                                               tokens
# 0  [sam, the, sham, miscellaneous, wooly, bully, ...
# ...

# %%
songs['tokens2'] = songs ['Lyrics'].map(lambda x: x.split()) #lambda function

# %%
#def get_avg_len(toks)
  #  lens = [len(t) for t in toks]
  #  return sum(lens/len(lens))

sent = 'colorless green ideas sleep furiously'.split()
sent
get_avg_len(sent)

songs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-6a4506ebd2af> in <module>()
#       5 sent = 'colorless green ideas sleep furiously'.split()
#       6 sent
# ----> 7 get_avg_len(sent)
#
# NameError: name 'get_avg_len' is not defined

# %%
import nltk
nltk.corpus.brown.words()
# Out:
# ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', ...]

# %%
nltk.word_tokenize('rose is a rose is a rose')
# Out:
# ['rose', 'is', 'a', 'rose', 'is', 'a', 'rose']

# %%
nltk.word_tokenize('i have not seen star wars')
# Out:
# ['i', 'have', 'not', 'seen', 'star', 'wars']

# %%
nltk.sent_tokenize('hell eartlings. you are really stupid to be taking this course. why are you doing it?')
# Out:
# ['hell eartlings.', 'you are really stupid to be taking this course.', 'why are you doing it?']

# %%
#jacor.sents gives you a word tokenized list of sentences
# check the Summary on Lab13 file maker pro

# %%
import nltk
nltk.corpus.brown.words()

# %%
songs['ttr'] = songs['tokens'].map(get_ttr)
songs.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-cc5e9a06bc50> in <module>()
# ----> 1 songs['ttr'] = songs['tokens'].map(get_ttr)
#       2 songs.head()
#
# NameError: name 'get_ttr' is not defined
