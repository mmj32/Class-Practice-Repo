# %% [markdown]
# # 50 Years of Pop Music: A Lyrical Analysis
#
# - Class activity 3, 9/12/2017
# - Data courtesy of Kaylin Walker: http://kaylinwalker.com/50-years-of-pop-music/

# %% [markdown]
# ## (1) Read in the spreadsheet file as a DataFrame
# - Create a DataFrame called `songs` from the spreadsheet.
# - You will likely run into an encoding error. Who can figure out the correct encoding?
# - Once successfully loaded, explore the DF. Use the following methods: `.head()`, `.tail()`, `.info()`, `.describe()`.
# - What are the column labels and row indexes?
# - How to improve organization?

# %%
import pandas as pd

pop = pd.read_csv('/Users/Paige/Desktop/billboard_lyrics_1964-2015.csv', encoding='ISO8859')

#How to find the encoding of a file?
#file billboard_lyrics_1964-2015.csv in command line

pop.head() #.head shows you the first 5 entries

pop.head(20) #shows you the first 20

pop.tail() #.tail shows you the last 5 entries

pop.info() #Note: Pandas stores strings in other memory locations as objects and puts a pointer to it

pop.describe() #displays count, mean, std, min, 25%, 50%, 75%, max for columns with numerical data

pop.head(20) #Indices are default integers

pop.loc[:][pop.Artist == 'one direction'] #Here are 5 One Direction songs in the top 100 because we are all really big 1D fans.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5100 entries, 0 to 5099
# Data columns (total 6 columns):
# Rank      5100 non-null int64
# Song      5100 non-null object
# Artist    5100 non-null object
# Year      5100 non-null int64
# Lyrics    4913 non-null object
# Source    4913 non-null float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 239.1+ KB
#       Rank                      Song         Artist  Year  \
# 4709    10  what makes you beautiful  one direction  2012
# 4873    74            best song ever  one direction  2013
# 4923    24          story of my life  one direction  2014
# 5064    65              drag me down  one direction  2015
# 5097    98             night changes  one direction  2015
#
#                                                  Lyrics  Source
# 4709   youre insecure dont know what for youre turni...     1.0
# 4873   maybe its the way she walked wow straight int...     1.0
# 4923   verse 1  harry written in these walls are the...     1.0
# 5064   ive got fire for a heart im not scared of the...     1.0
# 5097   going out tonight changes into something red ...     1.0

# %% [markdown]
# ## (2) Reorganize and clean up
# - Rearrange the columns so that they are ordered: Year - Rank - Artist - Song - Lyrics.
# - Get rid of Source column.
# - What about the index?

# %%
pop = pop[['Year', 'Rank', 'Artist', 'Song', 'Lyrics']] #Need double brackets, cause if you use one, a Pandas series is returned
type(pop)
pop.head()
# Out:
#    Year  Rank                         Artist  \
# 0  1965     1  sam the sham and the pharaohs
# 1  1965     2                      four tops
# 2  1965     3             the rolling stones
# 3  1965     4                        we five
# 4  1965     5         the righteous brothers
#
#                                        Song  \
# 0                               wooly bully
# 1  i cant help myself sugar pie honey bunch
# 2                i cant get no satisfaction
# 3                       you were on my mind
# 4              youve lost that lovin feelin
#
#                                               Lyrics
# 0  sam the sham miscellaneous wooly bully wooly b...
# 1   sugar pie honey bunch you know that i love yo...
# 2
# 3   when i woke up this morning you were on my mi...
# 4   you never close your eyes anymore when i kiss...

# %%
type(pop['Artist']) #A single column is a series!
pop.loc[2]
type(pop['Lyrics'][2]) #str
len(pop['Lyrics'][2]) #2
type(pop['Lyrics'][45]) #float!

#ways to look up

pop.loc[48][2]
pop.loc[48, 'Lyrics']
# Out:
# 'well east coast girls are hip i really dig those styles they wear and the southern girls with the way they talk they knock me out when im down there the midwest farmers daughter really makes you feel alright and the northern girls with the way they kiss they keep their boyfriends warm at night i wish they all could be california wish they all could be california i wish they all could be california girls the west coast has the sunshine and the girls all get so tan i dig a french bikini on hawiian island dollsby a palm tree in the sand i been all round this great big world and i seen all kinds of girls yeah but i couldnt wait to get back in the states back to the cutest girls in the world i wish they all could be california wish they all could be california i wish they all could be california girls i wish they all could be california wish they all could be california i wish they all could be california girls'

# %%
# %pprint
# Out:
# Pretty printing has been turned OFF

# %% [markdown]
# ## (3) Sanity check
# - Is the data complete?
#   - Are there really 50 years represented?
#   - Does every year have all 100 entries?
# - Any missing or anomalous data? How to address them?

# %%
#Are there 50 years?
set(pop['Year'])
len(set(pop['Year']))
#also pop['Year']

#There's a better way!

pop['Year'] #This is a series
len(pop['Year'].drop_duplicates())
pop['Year'].unique()
pop['Year'].min()
pop['Year'].max()
pop['Year'].unique().size

pop['Rank'].unique() #100!
#Each rank should be represented 51 times

pop['Year'].value_counts() #or
pop['Rank'].value_counts().sort_index()
# Out:
# 1      51
# 2      51
# 3      51
# 4      51
# 5      51
# 6      51
# 7      51
# 8      51
# 9      51
# 10     51
# 11     51
# 12     51
# 13     51
# 14     51
# 15     51
# 16     51
# 17     51
# 18     51
# 19     51
# 20     51
# 21     51
# 22     51
# 23     51
# 24     51
# 25     51
# 26     51
# 27     51
# 28     51
# 29     51
# 30     51
#        ..
# 71     51
# 72     51
# 73     51
# 74     51
# 75     51
# 76     51
# 77     51
# 78     51
# 79     51
# 80     51
# 81     51
# 82     51
# 83     51
# 84     51
# 85     51
# 86     51
# 87     51
# 88     51
# 89     51
# 90     51
# 91     51
# 92     51
# 93     51
# 94     51
# 95     51
# 96     51
# 97     51
# 98     51
# 99     51
# 100    51
# Name: Rank, Length: 100, dtype: int64

# %% [markdown]
# ## (4) Accessing routines
# - How to get songs from year 1965 vs. songs from year 2015?
# - How to get number-1 hits only?
# - How to get Madonna songs only?
# - Madonna songs that are top 10? Year 2000 or later?

# %%
newfilter = pop['Year'] == 1965
oldies = pop.loc[newfilter, :]
df15 = pop.loc[pop['Year']==2013, :]
df15
#or!
#df15 = pop.iloc[-100:, :] #HAVE to use iloc with negative index
number1 = pop.loc[pop['Rank']==1, :]
number1
oldies
df15
pop.loc[pop['Artist']=='madonna', :]

# control + / comments out a highlighted section
# Out:
#       Year  Rank   Artist                           Song  \
# 1934  1984    35  madonna                     borderline
# 1965  1984    66  madonna                     lucky star
# 1978  1984    79  madonna                        holiday
# 2001  1985     2  madonna                  like a virgin
# 2008  1985     9  madonna                  crazy for you
# 2057  1985    58  madonna                  material girl
# 2080  1985    81  madonna                          angel
# 2097  1985    98  madonna                   dress you up
# 2128  1986    29  madonna               papa dont preach
# 2134  1986    35  madonna                   live to tell
# 2175  1986    76  madonna                      true blue
# 2229  1987    30  madonna                open your heart
# 2241  1987    42  madonna                 whos that girl
# 2245  1987    46  madonna            causing a commotion
# 2257  1987    58  madonna                 la isla bonita
# 2424  1989    25  madonna                  like a prayer
# 2454  1989    55  madonna               express yourself
# 2458  1989    59  madonna                        cherish
# 2504  1990     5  madonna                          vogue
# 2620  1991    21  madonna                justify my love
# 2720  1992    21  madonna  this used to be my playground
# 2865  1993    66  madonna              deeper and deeper
# 2866  1993    67  madonna                           rain
# 2912  1994    13  madonna                   ill remember
# 2983  1994    84  madonna                         secret
# 3007  1995     8  madonna                     take a bow
# 3070  1995    71  madonna                         secret
# 3150  1996    51  madonna                      youll see
# 3286  1997    87  madonna      dont cry for me argentina
# 3298  1997    99  madonna               you must love me
# 3331  1998    32  madonna                         frozen
# 3374  1998    75  madonna                   ray of light
# 3516  2000    17  madonna                          music
# 3633  2001    34  madonna                   dont tell me
# 4190  2006    91  madonna                        hung up
#
#                                                  Lyrics
# 1934   something in the way you love me wont let me ...
# 1965   you must be my lucky star cause you shine on ...
# 1978   holiday celebrate holiday celebrateif we took...
# 2001   i made it through the wilderness somehow i ma...
# 2008   swaying room as the music starts strangers ma...
# 2057   some boys kiss me some boys hug me i think th...
# 2080   why am i standing on a cloud every time youre...
# 2097   youve got style thats what all the girls say ...
# 2128
# 2134   i have a tale to tell sometimes it gets so ha...
# 2175   ive had other guys ive looked into their eyes...
# 2229   watch outi see you on the street and you walk...
# 2241   whos that girl whos that girlwhen you see her...
# 2245   ive got the moves baby youve got the motion i...
# 2257   como puede ser verdadlast night i dreamt of s...
# 2424   life is a mystery everyone must stand alone i...
# 2454   baby bbbbaby come on girls you believe in lov...
# 2458   so tired of broken hearts and losing at this ...
# 2504   strike a pose strike a pose vogue vogue vogue...
# 2620   i want to kiss you in paris i want to hold yo...
# 2720   this used to be my playground this used to be...
# 2865   deeper and deeper and deeper and deeper sweet...
# 2866   i feel it its coming rainfeel it on my finger...
# 2912   hmm hmm say goodbye not knowing when the trut...
# 2983   things havent been the same since you came in...
# 3007   take a bow the night is over this masquerade ...
# 3070   things havent been the same since you came in...
# 3150   you think that i cant live without your love ...
# 3286   it wont be easy youll think it strange when i...
# 3298   where do we go from here this isnt where we i...
# 3331   you only see what your eyes want to see how c...
# 3374   zephyr in the sky at night i wonder do my tea...
# 3516   hey mister dj put a record on i want to dance...
# 3633   dont tell me to stop tell the rain not to dro...
# 4190   time goes by so slowly time goes by so slowly...

# %%
#Madonna songs only
pop.loc[pop['Artist'] == 'madonna', :]

pop.loc[(pop['Artist'] == 'madonna') & (pop['Year']>=2000), :]
# Out:
#       Year  Rank   Artist          Song  \
# 3516  2000    17  madonna         music
# 3633  2001    34  madonna  dont tell me
# 4190  2006    91  madonna       hung up
#
#                                                  Lyrics
# 3516   hey mister dj put a record on i want to dance...
# 3633   dont tell me to stop tell the rain not to dro...
# 4190   time goes by so slowly time goes by so slowly...

# %% [markdown]
# ## (5) Who are top artists?
# - How many artists are represented?
# - Which artists produced most hits?
# - How many artists are one-hit wonders?

# %%
dir(pop['Artist'])

pop['Artist'].unique().size

pop['Artist'].value_counts()[:20]

onehit = pop['Artist'].value_counts()[pop['Artist'].value_counts()==1] #pop['Artist'].value_counts() is a series and we are providing a 1D filter for it.

onehit.size
# Out:
# 1628

# %% [markdown]
# ## (6) Create another column: lyric length in word count
# - All symbols have been removed from lyrics
# - So, `.split()` works as a rudimentary tokenizer

# %%
len(pop.loc[0, 'Lyrics'].split())

foo = pop[:50]
foo

for x in foo['Lyrics']:
    print(len(x.split()))
# Out:
# 125
# 204
# 0
# 152
# 232
# 239
# 228
# 215
# 148
# 153
# 299
# 169
# 204
# 241
# 134
# 222
# 170
# 1
# 198
# 233
# 176
# 155
# 166
# 148
# 138
# 85
# 184
# 137
# 291
# 154
# 273
# 139
# 113
# 260
# 287
# 280
# 235
# 144
# 217
# 134
# 391
# 0
# 123
# 271
# 0
# 0
# 161
# 160
# 180
# 178

# %%
foo
[x for x in [1,2,3,4]]
song_length = [len(x.split()) for x in pop['Lyrics']]
song_length[:100]

pop['Length'] = pd.Series(song_length)
pop.head()

#Other ways!

def tokenize(txt):
    return txt.split()

pop['Tokens'] = pop['Lyrics'].map(tokenize)

pop.head()

pop['tokens2'] = pop['Lyrics'].map(lambda x: x.split())
pop.head()

del pop['tokens2']
pop.head()
# Out:
#    Year  Rank                         Artist  \
# 0  1965     1  sam the sham and the pharaohs
# 1  1965     2                      four tops
# 2  1965     3             the rolling stones
# 3  1965     4                        we five
# 4  1965     5         the righteous brothers
#
#                                        Song  \
# 0                               wooly bully
# 1  i cant help myself sugar pie honey bunch
# 2                i cant get no satisfaction
# 3                       you were on my mind
# 4              youve lost that lovin feelin
#
#                                               Lyrics  Length  \
# 0  sam the sham miscellaneous wooly bully wooly b...     125
# 1   sugar pie honey bunch you know that i love yo...     204
# 2                                                          0
# 3   when i woke up this morning you were on my mi...     152
# 4   you never close your eyes anymore when i kiss...     232
#
#                                               Tokens
# 0  [sam, the, sham, miscellaneous, wooly, bully, ...
# 1  [sugar, pie, honey, bunch, you, know, that, i,...
# 2                                                 []
# 3  [when, i, woke, up, this, morning, you, were, ...
# 4  [you, never, close, your, eyes, anymore, when,...

# %%
def get_avg_length(tokens):
    length = [len(x) for x in tokens]
    if len(tokens) == 0:
        return 0
    else:
        return sum(length)/len(tokens)

get_avg_length(pop.loc[0]['Tokens'])

pop['avg_wd_len'] = pop['Tokens'].map(get_avg_length)
pop.head()
# Out:
#    Year  Rank                         Artist  \
# 0  1965     1  sam the sham and the pharaohs
# 1  1965     2                      four tops
# 2  1965     3             the rolling stones
# 3  1965     4                        we five
# 4  1965     5         the righteous brothers
#
#                                        Song  \
# 0                               wooly bully
# 1  i cant help myself sugar pie honey bunch
# 2                i cant get no satisfaction
# 3                       you were on my mind
# 4              youve lost that lovin feelin
#
#                                               Lyrics  Length  \
# 0  sam the sham miscellaneous wooly bully wooly b...     125
# 1   sugar pie honey bunch you know that i love yo...     204
# 2                                                          0
# 3   when i woke up this morning you were on my mi...     152
# 4   you never close your eyes anymore when i kiss...     232
#
#                                               Tokens  avg_wd_len
# 0  [sam, the, sham, miscellaneous, wooly, bully, ...    4.280000
# 1  [sugar, pie, honey, bunch, you, know, that, i,...    3.872549
# 2                                                 []    0.000000
# 3  [when, i, woke, up, this, morning, you, were, ...    3.546053
# 4  [you, never, close, your, eyes, anymore, when,...    4.051724

# %% [markdown]
# ## (7) Filling in missing values
# - We really need to take care of the missing lyric values.
# - What are good strategies? Considerations?

# %%
#pop = pop.fillna('')

pop.fillna('')#doesnt change the original
pop.fillna('', inplace=True) #chagnes thes original!

# %% [markdown]
# ## (8) A detour: text processing basics
# - NLTK functions
# - How to word-tokenize
# - How to sentence-tokenize
# - Frequency distribution
# - Type-token ratio

# %%
#TTR
def ttr(tokens):
    if len(tokens) == 0:
        return 0
    else:
        return len(set(tokens))/len(tokens)

pop['TTR'] = pop.Tokens.map(ttr)
pop.head()
# Out:
#    Year  Rank                         Artist  \
# 0  1965     1  sam the sham and the pharaohs
# 1  1965     2                      four tops
# 2  1965     3             the rolling stones
# 3  1965     4                        we five
# 4  1965     5         the righteous brothers
#
#                                        Song  \
# 0                               wooly bully
# 1  i cant help myself sugar pie honey bunch
# 2                i cant get no satisfaction
# 3                       you were on my mind
# 4              youve lost that lovin feelin
#
#                                               Lyrics  Length  \
# 0  sam the sham miscellaneous wooly bully wooly b...     125
# 1   sugar pie honey bunch you know that i love yo...     204
# 2                                                          0
# 3   when i woke up this morning you were on my mi...     152
# 4   you never close your eyes anymore when i kiss...     232
#
#                                               Tokens  avg_wd_len       TTR
# 0  [sam, the, sham, miscellaneous, wooly, bully, ...    4.280000  0.512000
# 1  [sugar, pie, honey, bunch, you, know, that, i,...    3.872549  0.460784
# 2                                                 []    0.000000  0.000000
# 3  [when, i, woke, up, this, morning, you, were, ...    3.546053  0.289474
# 4  [you, never, close, your, eyes, anymore, when,...    4.051724  0.379310

# %% [markdown]
# ## (9) 50 years apart: songs from 1965 vs. 2015
# - Let's create two corpora of 1965 lyrics vs. 2015 lyrics
# - Good ways to highlight differences?

# %%
# Your code here

# %% [markdown]
# ## (10) A different take: multi-level index
# - Alternative organization: use year-and-rank combination as index
# - Create a copy of `songs` as `songs2` DataFrame
# - How does accessing work in this DF?

# %%
# Your code here

# %% [markdown]
# ## (11) Discussion: data curation method, presentation
# - How did Walker collect her song lyrics data?
# - What tools did she use?
# - How successful was her effort?
# - How did she present her work, and what are your thoughts?

# %% [markdown]
# Your notes here in markdown
