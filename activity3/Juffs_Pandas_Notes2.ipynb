# %% [markdown]
# This is a file for Juffs' Notes on Pandas.
# Todo3, September 11, 2017.
# juffs@pitt.edu
#
# I am updating these notes for 'todo4'.
# Specifically, I looked at Paige Haring's code as she is in my group and seems very good at getting the code correct.
#
# Added on September 16: Notes from datacamp.
#
# Added on September 19: Notes about matplotlib and more on data frames.

# %% [markdown]
# These are notes about dictionaries

# %%
# Definition of dictionary
europe = {'spain':'madrid', 'france':'paris', 'germany':'berlin', 'norway':'oslo' }

# Add italy to europe
europe["italy"] = 'rome'

# Print out italy in europe
print("italy" in europe)

# Add poland to europe
europe["poland"] = 'warsaw'

# Print europe
print(europe)
# Out:
# True
# {'spain': 'madrid', 'france': 'paris', 'germany': 'berlin', 'norway': 'oslo', 'italy': 'rome', 'poland': 'warsaw'}

# %% [markdown]
# I note that this code works, whereas in the Python data camp, this code did NOT work.

# %%
europe['germany'] = 'bonn'

# %%
print(europe)
# Out:
# {'spain': 'madrid', 'france': 'paris', 'germany': 'bonn', 'norway': 'oslo', 'italy': 'rome', 'poland': 'warsaw'}

# %% [markdown]
# You can build DATA FRAMES in Pandas from lists, as follows. Note that the dictionary can summarized for 'dict' using the names of the lists and the values do not have to be retyped. Remember that booleans and floats do not have '...', whereas str MUST have '...'.

# %%
import pandas as pd
# Build cars DataFrame
names = ['United States', 'Australia', 'Japan', 'India', 'Russia', 'Morocco', 'Egypt']
dr =  [True, False, False, False, True, True, True]
cpc = [809, 731, 588, 18, 200, 70, 45]
dict = { 'country':names, 'drives_right':dr, 'cars_per_cap':cpc }
cars = pd.DataFrame(dict)

# If you print the result of this code, you get numbered row labels. You can add them thus:
# Definition of row_labels
row_labels = ['US', 'AUS', 'JAP', 'IN', 'RU', 'MOR', 'EG']

# Specify row labels of cars
cars.index = row_labels

# Print cars again with the row labels
print(cars)
# Out:
#      cars_per_cap        country  drives_right
# US            809  United States          True
# AUS           731      Australia         False
# JAP           588          Japan         False
# IN             18          India         False
# RU            200         Russia          True
# MOR            70        Morocco          True
# EG             45          Egypt          True

# %% [markdown]
# However, creating all of your own files with lists and dictionaries is not very efficient. Instead, it is easier to read in .csv files and perform operations on those. Here are some real data from the ELI data project. It's a data file with a list of participants, a list of their L1s and their proficiency scores. I note that 'missing values' are indicated with a
# NaN string? Something to be looked into later.

# %%
import pandas as pd
ELIProfic = pd.read_csv("/Users/Juffs/Documents/Data_Science/Class-Practice-Repo/todo3/Pandas_Juffs_CSV.csv")

# %%
ELIProfic
# Out:
#     DB ID       L1  Listening  MTELP  Writing
# 0      71  chinese       10.0   56.0      NaN
# 1     118  chinese       23.0   61.0      NaN
# 2     270  chinese       12.0   35.0      1.5
# 3     298  chinese       16.0   57.0      4.0
# 4     299  chinese       10.0   42.0      3.3
# 5     447  chinese       21.0   55.0      3.2
# 6     201  chinese       22.0   66.0      NaN
# 7     278  chinese       25.0   69.0      NaN
# 8     396  chinese       23.0   77.0      3.8
# 9     441  chinese       21.0   62.0      3.5
# 10    453  chinese       23.0   63.0      2.8
# 11    491  chinese       23.0   71.0      3.3
# 12    492  chinese       17.0   58.0      3.8
# 13    634  chinese       21.0   59.0      3.5
# 14    813  chinese       27.0   65.0      3.5
# 15    967  chinese       26.0   67.0      4.3
# 16    971  chinese       26.0   60.0      3.6
# 17    975  chinese       12.0   62.0      4.3
# 18    998  chinese       21.0   63.0      3.3
# ...

# %% [markdown]
# From Paige's code,  I learned the the following:
#     1. You can comment on the code with the # sign in the same line as code.
#     2. You can print everything with '\n'
#     3. You have to pay attention to the [ ] and (). It seems that () are operations and [] are lists and part of dictionaries { }.

# %%
import numpy as np
import pandas as pd
avgs = {'Cary': 90, 'Alex': 95, 'Stephanie': 70, 'Steven':63}
student_avgs = pd.Series(avgs) #NOTE: The dictionary is rearranged alphabetically by key
print(student_avgs, '\n')
print(student_avgs['Alex'], '\n')
print(student_avgs['Alex':'Stephanie']) #NOTE: This includes the value at the Stephanie index
# Out:
# Alex         95
# Cary         90
# Stephanie    70
# Steven       63
# dtype: int64
#
# 95
#
# Alex         95
# Cary         90
# Stephanie    70
# dtype: int64

# %%
rng = np.random.RandomState(42)
bingo = pd.DataFrame(rng.randint(0, 100, (5, 5)),
                  columns=['B', 'I', 'N', 'G', 'O'])
bingo
# Out:
#     B   I   N   G   O
# 0  51  92  14  71  60
# 1  20  82  86  74  74
# 2  87  99  23   2  21
# 3  52   1  87  29  37
# 4   1  63  59  20  32

# %%
rng = np.random.RandomState(42)
bingo = pd.DataFrame(rng.randint(0, 100, (5, 5)),
                  columns=['B', 'I', 'N', 'G', 'O'])
bingo
# Out:
#     B   I   N   G   O
# 0  51  92  14  71  60
# 1  20  82  86  74  74
# 2  87  99  23   2  21
# 3  52   1  87  29  37
# 4   1  63  59  20  32

# %%
A = pd.DataFrame(rng.randint(0, 20, (2, 2)),
                 columns=list('AB'))
A #I also noticed that by calling the data set in a second line HERE, it gives you the output.
# Out:
#     A   B
# 0  11  11
# 1  16   9

# %% [raw]
# From Data Camp September 16 2017

# %%
import numpy as np
import pandas as pd

# %%
# You can manipulate import of columns of a .csv file with the 'index.col' command
# Fix import by including index_col
#cars = pd.read_csv('cars.csv', index_col = 0)

# %% [markdown]
# # Import cars data
# import pandas as pd
# cars = pd.read_csv('cars.csv', index_col = 0)
#
# # Print out drives_right column as Series
# print(cars.loc [ : , 'drives_right'])
#
# # Print out drives_right column as DataFrame
# print(cars.loc [ : , ['drives_right']])
#
# # Print out cars_per_cap and drives_right as DataFrame
# print(cars.loc[:, ['cars_per_cap', 'drives_right']])

# %% [markdown]
# Notes from matplot.lib in the Intermediate Python.

# %% [markdown]
# Plotting Codes
#
# LINE PLOT
# # Print the last item from year and pop
# print(year[len(year) - 1])
# print(pop[len(pop) - 1])
#
# # Import matplotlib.pyplot as plt
# import matplotlib.pyplot as plt
#
# # Make a line plot: year on the x-axis, pop on the y-axis
# plt.plot(year,pop)
#
#
# SCATTER PLOT
#
# # Display the plot with plt.show()
# plt.show()
#
# # Change the line plot below to a scatter plot
# plt.scatter(gdp_cap, life_exp)
#
# # Put the x-axis on a logarithmic scale
# plt.xscale('log')
#
# # Show plot
# plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
new_labels = ['Part', 'Age of Arr', 'Age at Test', 'TestScore', 'Aptitude', 'Years of Ed', 'Group']

# %%
RDK_CRIT = pd.read_csv("/Users/Juffs/Documents/Data_Science/Class-Practice-Repo/todo5/rdk_critical_period.csv")

# %%
RDK_CRIT.head()
# Out:
#    id  arrival  age   gj  aptitude  school  group
# 0   1       28   68  136         3       6  Older
# 1   2        8   46  170         4       6  Young
# 2   3       11   51  181         5      12  Young
# 3   4       20   59  132         5      14  Older
# 4   5       23   60  139        10      12  Young

# %%
import pandas as pd
type(RDK_CRIT)
RDK_CRIT.shape
RDK_CRIT.columns
# Out:
# Index(['id', 'arrival', 'age', 'gj', 'aptitude', 'school', 'group'], dtype='object')

# %%
RDK_CRIT.iloc[:, 4:]
# Out:
#     aptitude  school  group
# 0          3       6  Older
# 1          4       6  Young
# 2          5      12  Young
# 3          5      14  Older
# 4         10      12  Young
# 5          8      14  Older
# 6          5      17  Older
# 7          9      18  Older
# 8          9      17  Older
# 9          4      16  Young
# 10         8      16  Young
# 11         4      20  Young
# 12         4      18  Older
# 13         4      16  Older
# 14         3       8  Older
# 15         5       8  Older
# 16         5       6  Older
# 17         6       8  Older
# 18         4      18  Young
# 19         5      18  Young
# 20         4      18  Young
# 21         2      12  Older
# 22         4      16  Young
# 23         2      20  Young
# 24         2      16  Young

# %%
RDK_CRIT.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 7 columns):
# id          25 non-null int64
# arrival     25 non-null int64
# age         25 non-null int64
# gj          25 non-null int64
# aptitude    25 non-null int64
# school      25 non-null int64
# group       25 non-null object
# dtypes: int64(6), object(1)
# memory usage: 1.4+ KB

# %%
RDK_CRIT.columns
# Out:
# Index(['id', 'arrival', 'age', 'gj', 'aptitude', 'school', 'group'], dtype='object')

# %%
RDK_CRIT = RDK_CRIT.rename(columns= {'gj':'TestScore'})
RDK_CRIT.head() # check to make sure re-assignment worked = 'Briannas code'
# Out:
#    id  arrival  age  TestScore  aptitude  school  group
# 0   1       28   68        136         3       6  Older
# 1   2        8   46        170         4       6  Young
# 2   3       11   51        181         5      12  Young
# 3   4       20   59        132         5      14  Older
# 4   5       23   60        139        10      12  Young

# %%
# create a scatter plot
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
RDK_CRIT.info
# Out:
# <bound method DataFrame.info of     id  arrival  age  TestScore  aptitude  school  group
# 0    1       28   68        136         3       6  Older
# 1    2        8   46        170         4       6  Young
# 2    3       11   51        181         5      12  Young
# 3    4       20   59        132         5      14  Older
# 4    5       23   60        139        10      12  Young
# 5    6       22   56        153         8      14  Older
# 6    7       30   75        141         5      17  Older
# 7    8       27   50        147         9      18  Older
# 8    9       27   64        175         9      17  Older
# 9   10        9   54        198         4      16  Young
# 10  11       11   57        194         8      16  Young
# 11  12       13   58        196         4      20  Young
# 12  13       27   67        170         4      18  Older
# 13  14       27   66        126         4      16  Older
# 14  15       23   63        110         3       8  Older
# ...

# %%
RDK_CRIT.columns
# Out:
# Index(['id', 'arrival', 'age', 'TestScore', 'aptitude', 'school', 'group'], dtype='object')

# %%
RDK_CRIT = pd.DataFrame(RDK_CRIT, columns = ['id', 'arrival', 'age', 'TestScore', 'aptitude', 'school', 'group'])

# %%
plt.scatter(RDK_CRIT.arrival, RDK_CRIT.TestScore)
# Chart title
plt.title('Age Effects')

# y label
plt.ylabel('Test Score')

# x label
plt.xlabel('Age of Arrival')
plt.show()
